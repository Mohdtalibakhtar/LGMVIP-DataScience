# %% [markdown]
# ## LGM-VIP Task 1 Image to Pencil Sketch with Python

# %% [markdown]
# ### Author : Mohd Talib Akhtar

# %%
from PIL import Image
from IPython.display import display
import cv2

# %%
image = cv2.imread('Me.jpg', 1)
image = cv2.resize(image, (600, 600))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x226D8CF1748>

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grey_image))
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x226D8CF1400>

# %%
image_inv = cv2.bitwise_not(grey_image)
display(Image.fromarray(image_inv))
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x226D8D770F0>

# %%
image_smooth = cv2.GaussianBlur(image_inv, (21, 21), 0) 
display(Image.fromarray(image_smooth))
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x226D8D77390>

# %%
inverted_image = 255 - grey_image
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(grey_image, inverted_blurred, scale=256.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x226D8D80748>
